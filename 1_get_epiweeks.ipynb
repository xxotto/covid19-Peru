# %% [markdown]
# # 0. Run libraries and functions

# %%
import pandas as pd
import numpy as np

import functions as fn



def just_dates(vac_url, fal_url):
    """
    Función para filtrar a cada vacunado y fallecido reportado en su año
    y semana epidemiológica (Fallecidos = fal, Vacunados = vac)

    Parameters
    ----------
    vac_url: Directorio o url del dataset de VACUNADOS contra COVID-19
    fal_url: Directorio o url del dataset de FALLECIDOS por COVID-19

    Returns
    -------
    lst_vac: Lista de 'chunks' o dataframes de tamaño n de VACUNADOS
    df_fal: Dataframe de FALLECIDOS

    """
    vac_col = ['fecha_vacunacion']  # Seleccionar solamente la columna de fechas de ambos datasets                         
    fal_col = ['FECHA_FALLECIMIENTO']
    
    df_vac = fn.read_largeCSV_file(vac_url, ',', vac_col)   # Leemos los datasets       
    df_fal = fn.read_largeCSV_file(fal_url, ';', fal_col)
    
    fn.variable_fecha_ymd(df_vac, 'fecha_vacunacion')   # Transformamos a formato fecha (datetime64[ns])            
    fn.variable_fecha(df_fal, 'FECHA_FALLECIMIENTO')
    fn.date_to_epiweek(df_fal,'FECHA_FALLECIMIENTO')    # Obtenemos semana epidemiológica de fallecidos              
    
    lst_vac = fn.df_into_chunks(df_vac)   #  Dividimos en chunks el dataset de vacunados  

    # Obtenemos semana epidemiológica de vacunados para cada chunk
    for chunk in lst_vac:                                           
        chunk = fn.date_to_epiweek(chunk, 'fecha_vacunacion')

    # Creamos columnas de 1 para contabilizar cada caso de fallecido
    df_fal['fallecido'] = 1                                         
    df_fal['fallecido'].apply(np.int8) 
    df_fal.info()
    
    # Creamos columnas de 1 en cada chunk para contabilizar cada caso de vacunado
    for chunk in lst_vac:                                        
        chunk['vacunado'] = 1
        chunk['vacunado'].apply(np.int8)
        del chunk
    
    return lst_vac, df_fal
    


def epiweeks(df_fal):
    """
    Devuelve un dataframe con el total de FALLECIDOS por semana y año 
    epidemiológico
    """
    epi_fal = pd.crosstab(index=[df_fal['epi_year'],
                                 df_fal['epi_week']],
                          columns=df_fal['fallecido'])
    epi_fal.columns = ['fallecidos']    
    
    return epi_fal
    
  
    
def epiweeks_chunks(dfs_vac):
    """
    Devuelve un dataframe con el total de VACUNADOS por semana y año 
    epidemiológico (recibe una lista de dataframes o chunks)
    """
    var_holder = {}     # Diccionario para guardar nombres                                             
    lst_epi_vac = []    # Lista de dfs para cada sumatoria de chunks
                                         
    for i, chunk in enumerate(dfs_vac):
        var_holder['epi_vac_' + str(i)]= pd.crosstab(index=[chunk['epi_year'],
                                                            chunk['epi_week']],
                                                     columns=chunk['vacunado'])
        lst_epi_vac.append(var_holder['epi_vac_' + str(i)])
    # Unimos todos los dfs sumados en uno solo
    merged_epivac = pd.concat(lst_epi_vac, axis=1) 
    epi_vac = pd.DataFrame(merged_epivac.sum(numeric_only=True, axis=1))
    epi_vac.columns = ['vacunados']
    
    return epi_vac
  
    
  
def merged_epiweeks(epi_vac, epi_fal):
    """
    Junta los 2 dataframes resultantes, el del total de vacunados y del total de 
    fallecidos por semana epidemiológica
    """
    # Concatenamos ambos dataframes (hay Nan values)
    merged_epiweeks = pd.concat([epi_fal, epi_vac], axis=1)         
    merged_epiweeks = merged_epiweeks.fillna(value = 0)
    # Cambiamos a Int64 ya que existen Nan values y cambia a float64 automáticamente
    merged_epiweeks = merged_epiweeks.astype('Int64')
    merged_epiweeks = merged_epiweeks.rename({'fallecidos': 'deceased', 'vacunados': 'vaccinated'}, axis=1) 
    
    return merged_epiweeks

# %% [markdown]
# # 1. Check if the rawdata still have the same format as the used in this code

# %%
vac_url = 'RawData/TB_VACUNACION_COVID19.csv'
fal_url = 'RawData/fallecidos_covid.csv'

df_vac = pd.read_csv(vac_url, sep=',', nrows= 3)
print("Dataset of all those vaccinated against COVID-19 in Peru:")
print(df_vac), print("\n")
df_vac.info(), print("\n")

df_fal = pd.read_csv(fal_url, sep=';', nrows= 3)
print("Dataset of all those deceased by COVID-19 in Peru:")
print(df_fal), print("\n")
df_fal.info()

del df_vac
del df_fal
# Out:
# Dataset of all those vaccinated against COVID-19 in Peru:
#    id_persona  id_vacunados_covid19 fecha_vacunacion  id_eess  \
# 0    14395344              11932154       19/07/2021     5814
# 1    15330904              13342810       17/06/2021     4339
# 2    15611041              13342938       11/06/2021     3617
#
#    id_centro_vacunacion  id_vacuna  id_grupo_riesgo  dosis  edad
# 0                    17          5               62      2    57
# 1                  1828          5               54      2    69
# 2                103617          2               54      2    70
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id_persona            3 non-null      int64
#  1   id_vacunados_covid19  3 non-null      int64
#  2   fecha_vacunacion      3 non-null      object
#  3   id_eess               3 non-null      int64
#  4   id_centro_vacunacion  3 non-null      int64
#  5   id_vacuna             3 non-null      int64
#  6   id_grupo_riesgo       3 non-null      int64
#  7   dosis                 3 non-null      int64
#  8   edad                  3 non-null      int64
# dtypes: int64(8), object(1)
# memory usage: 344.0+ bytes
#
#
# Dataset of all those deceased by COVID-19 in Peru:
#    FECHA_CORTE  FECHA_FALLECIMIENTO  EDAD_DECLARADA       SEXO  \
# 0     20211030             20210425              70  MASCULINO
# 1     20211030             20210428              70  MASCULINO
# 2     20211030             20210430              59   FEMENINO
#
#       CLASIFICACION_DEF DEPARTAMENTO PROVINCIA                 DISTRITO  \
# 0  Criterio virolÃ³gico         LIMA      LIMA  VILLA MARIA DEL TRIUNFO
# 1  Criterio virolÃ³gico         LIMA      LIMA   SAN JUAN DE MIRAFLORES
# 2  Criterio virolÃ³gico     AYACUCHO    HUANTA                   HUANTA
#
#    UBIGEO  id_persona
# 0  150143    24693187
# 1  150133    24693271
# 2   50401    24735448
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   FECHA_CORTE          3 non-null      int64
#  1   FECHA_FALLECIMIENTO  3 non-null      int64
#  2   EDAD_DECLARADA       3 non-null      int64
#  3   SEXO                 3 non-null      object
#  4   CLASIFICACION_DEF    3 non-null      object
#  5   DEPARTAMENTO         3 non-null      object
#  6   PROVINCIA            3 non-null      object
#  7   DISTRITO             3 non-null      object
#  8   UBIGEO               3 non-null      int64
#  9   id_persona           3 non-null      int64
# dtypes: int64(5), object(5)
# memory usage: 368.0+ bytes

# %% [markdown]
# # 2. Run code

# %%
if __name__ == '__main__':
    dfs_vac,df_fal = just_dates(vac_url, fal_url)
    
    epi_fal = epiweeks(df_fal)
    epi_vac = epiweeks_chunks(dfs_vac)
  
    epiweeks = merged_epiweeks(epi_vac, epi_fal)
    
del vac_url, fal_url

epiweeks.to_csv('Data/epi_weeks.csv')
# Out:
# Read csv with dask:  13.33286452293396 sec
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 34638125 entries, 0 to 544332
# Columns: 1 entries, fecha_vacunacion to fecha_vacunacion
# dtypes: object(1)
# memory usage: 2.4 GB
# Read csv with dask:  0.14126873016357422 sec
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200246 entries, 0 to 200245
# Columns: 1 entries, FECHA_FALLECIMIENTO to FECHA_FALLECIMIENTO
# dtypes: int64(1)
# memory usage: 1.5 MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200246 entries, 0 to 200245
# Data columns (total 2 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   epi_year  200246 non-null  int64
#  1   epi_week  200246 non-null  int64
# dtypes: int64(2)
# memory usage: 3.1 MB
# /home/xxotto/Documents/GitHub/covid19-peru/functions.py:135: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del df[date_name]
# /home/xxotto/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1738: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value[:, i].tolist(), pi)
# /home/xxotto/Documents/GitHub/covid19-peru/functions.py:137: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   '''
# /home/xxotto/Documents/GitHub/covid19-peru/functions.py:138: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Transformamos nuestra fecha dd/mm/yyyy objeto a formato fecha
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500000 entries, 0 to 499999
# Data columns (total 2 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   epi_year  500000 non-null  int64
#  1   epi_week  500000 non-null  int64
# dtypes: int64(2)
# memory usage: 11.4 MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500000 entries, 500000 to 999999
# Data columns (total 2 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   epi_year  500000 non-null  int64
#  1   epi_week  500000 non-null  int64
# dtypes: int64(2)
# memory usage: 11.4 MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500000 entries, 1000000 to 181831
# Data columns (total 2 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   epi_year  500000 non-null  int64
#  1   epi_week  500000 non-null  int64
# dtypes: int64(2)
# memory usage: 11.4 MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500000 entries, 181832 to 681831
# Data columns (total 2 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   epi_year  500000 non-null  int64
#  1   epi_week  500000 non-null  int64
# dtypes: int64(2)
# memory usage: 11.4 MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500000 entries, 681832 to 1181831
# Data columns (total 2 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   epi_year  500000 non-null  int64
#  1   epi_week  500000 non-null  int64
# dtypes: int64(2)
# memory usage: 11.4 MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500000 entries, 1181832 to 363418
# Data columns (total 2 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   epi_year  500000 non-null  int64
#  1   epi_week  500000 non-null  int64
# dtypes: int64(2)
# memory usage: 11.4 MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500000 entries, 363419 to 863418
# Data columns (total 2 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   epi_year  500000 non-null  int64
#  1   epi_week  500000 non-null  int64
# dtypes: int64(2)
# memory usage: 11.4 MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500000 entries, 863419 to 44795
# Data columns (total 2 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   epi_year  500000 non-null  int64
#  1   epi_week  500000 non-null  int64
# dtypes: int64(2)
# memory usage: 11.4 MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500000 entries, 44796 to 544795
# Data columns (total 2 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   epi_year  500000 non-null  int64
#  1   epi_week  500000 non-null  int64
# dtypes: int64(2)
# memory usage: 11.4 MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500000 entries, 544796 to 1044795
# Data columns (total 2 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   epi_year  500000 non-null  int64
#  1   epi_week  500000 non-null  int64
# dtypes: int64(2)
# memory usage: 11.4 MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500000 entries, 1044796 to 236627
# Data columns (total 2 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   epi_year  500000 non-null  int64
#  1   epi_week  500000 non-null  int64
# dtypes: int64(2)
# memory usage: 11.4 MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500000 entries, 236628 to 736627
# Data columns (total 2 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   epi_year  500000 non-null  int64
#  1   epi_week  500000 non-null  int64
# dtypes: int64(2)
# memory usage: 11.4 MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500000 entries, 736628 to 1236627
# Data columns (total 2 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   epi_year  500000 non-null  int64
#  1   epi_week  500000 non-null  int64
# dtypes: int64(2)
# memory usage: 11.4 MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500000 entries, 1236628 to 435522
# Data columns (total 2 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   epi_year  500000 non-null  int64
#  1   epi_week  500000 non-null  int64
# dtypes: int64(2)
# memory usage: 11.4 MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500000 entries, 435523 to 935522
# Data columns (total 2 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   epi_year  500000 non-null  int64
#  1   epi_week  500000 non-null  int64
# dtypes: int64(2)
# memory usage: 11.4 MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500000 entries, 935523 to 136663
# Data columns (total 2 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   epi_year  500000 non-null  int64
#  1   epi_week  500000 non-null  int64
# dtypes: int64(2)
# memory usage: 11.4 MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500000 entries, 136664 to 636663
# Data columns (total 2 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   epi_year  500000 non-null  int64
#  1   epi_week  500000 non-null  int64
# dtypes: int64(2)
# memory usage: 11.4 MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500000 entries, 636664 to 1136663
# Data columns (total 2 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   epi_year  500000 non-null  int64
#  1   epi_week  500000 non-null  int64
# dtypes: int64(2)
# memory usage: 11.4 MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500000 entries, 1136664 to 338718
# Data columns (total 2 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   epi_year  500000 non-null  int64
#  1   epi_week  500000 non-null  int64
# dtypes: int64(2)
# memory usage: 11.4 MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500000 entries, 338719 to 838718
# Data columns (total 2 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   epi_year  500000 non-null  int64
#  1   epi_week  500000 non-null  int64
# dtypes: int64(2)
# memory usage: 11.4 MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500000 entries, 838719 to 40082
# Data columns (total 2 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   epi_year  500000 non-null  int64
#  1   epi_week  500000 non-null  int64
# dtypes: int64(2)
# memory usage: 11.4 MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500000 entries, 40083 to 540082
# Data columns (total 2 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   epi_year  500000 non-null  int64
#  1   epi_week  500000 non-null  int64
# dtypes: int64(2)
# memory usage: 11.4 MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500000 entries, 540083 to 1040082
# Data columns (total 2 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   epi_year  500000 non-null  int64
#  1   epi_week  500000 non-null  int64
# dtypes: int64(2)
# memory usage: 11.4 MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500000 entries, 1040083 to 236555
# Data columns (total 2 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   epi_year  500000 non-null  int64
#  1   epi_week  500000 non-null  int64
# dtypes: int64(2)
# memory usage: 11.4 MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500000 entries, 236556 to 736555
# Data columns (total 2 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   epi_year  500000 non-null  int64
#  1   epi_week  500000 non-null  int64
# dtypes: int64(2)
# memory usage: 11.4 MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500000 entries, 736556 to 1236555
# Data columns (total 2 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   epi_year  500000 non-null  int64
#  1   epi_week  500000 non-null  int64
# dtypes: int64(2)
# memory usage: 11.4 MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500000 entries, 1236556 to 420411
# Data columns (total 2 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   epi_year  500000 non-null  int64
#  1   epi_week  500000 non-null  int64
# dtypes: int64(2)
# memory usage: 11.4 MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500000 entries, 420412 to 920411
# Data columns (total 2 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   epi_year  500000 non-null  int64
#  1   epi_week  500000 non-null  int64
# dtypes: int64(2)
# memory usage: 11.4 MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500000 entries, 920412 to 103740
# Data columns (total 2 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   epi_year  500000 non-null  int64
#  1   epi_week  500000 non-null  int64
# dtypes: int64(2)
# memory usage: 11.4 MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500000 entries, 103741 to 603740
# Data columns (total 2 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   epi_year  500000 non-null  int64
#  1   epi_week  500000 non-null  int64
# dtypes: int64(2)
# memory usage: 11.4 MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500000 entries, 603741 to 1103740
# Data columns (total 2 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   epi_year  500000 non-null  int64
#  1   epi_week  500000 non-null  int64
# dtypes: int64(2)
# memory usage: 11.4 MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500000 entries, 1103741 to 287933
# Data columns (total 2 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   epi_year  500000 non-null  int64
#  1   epi_week  500000 non-null  int64
# dtypes: int64(2)
# memory usage: 11.4 MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500000 entries, 287934 to 787933
# Data columns (total 2 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   epi_year  500000 non-null  int64
#  1   epi_week  500000 non-null  int64
# dtypes: int64(2)
# memory usage: 11.4 MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500000 entries, 787934 to 1287933
# Data columns (total 2 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   epi_year  500000 non-null  int64
#  1   epi_week  500000 non-null  int64
# dtypes: int64(2)
# memory usage: 11.4 MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500000 entries, 1287934 to 472004
# Data columns (total 2 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   epi_year  500000 non-null  int64
#  1   epi_week  500000 non-null  int64
# dtypes: int64(2)
# memory usage: 11.4 MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500000 entries, 472005 to 972004
# Data columns (total 2 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   epi_year  500000 non-null  int64
#  1   epi_week  500000 non-null  int64
# dtypes: int64(2)
# memory usage: 11.4 MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500000 entries, 972005 to 156426
# Data columns (total 2 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   epi_year  500000 non-null  int64
#  1   epi_week  500000 non-null  int64
# dtypes: int64(2)
# memory usage: 11.4 MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500000 entries, 156427 to 656426
# Data columns (total 2 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   epi_year  500000 non-null  int64
#  1   epi_week  500000 non-null  int64
# dtypes: int64(2)
# memory usage: 11.4 MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500000 entries, 656427 to 1156426
# Data columns (total 2 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   epi_year  500000 non-null  int64
#  1   epi_week  500000 non-null  int64
# dtypes: int64(2)
# memory usage: 11.4 MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500000 entries, 1156427 to 340977
# Data columns (total 2 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   epi_year  500000 non-null  int64
#  1   epi_week  500000 non-null  int64
# dtypes: int64(2)
# memory usage: 11.4 MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500000 entries, 340978 to 840977
# Data columns (total 2 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   epi_year  500000 non-null  int64
#  1   epi_week  500000 non-null  int64
# dtypes: int64(2)
# memory usage: 11.4 MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500000 entries, 840978 to 26311
# Data columns (total 2 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   epi_year  500000 non-null  int64
#  1   epi_week  500000 non-null  int64
# dtypes: int64(2)
# memory usage: 11.4 MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500000 entries, 26312 to 526311
# Data columns (total 2 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   epi_year  500000 non-null  int64
#  1   epi_week  500000 non-null  int64
# dtypes: int64(2)
# memory usage: 11.4 MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500000 entries, 526312 to 1026311
# Data columns (total 2 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   epi_year  500000 non-null  int64
#  1   epi_week  500000 non-null  int64
# dtypes: int64(2)
# memory usage: 11.4 MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500000 entries, 1026312 to 210608
# Data columns (total 2 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   epi_year  500000 non-null  int64
#  1   epi_week  500000 non-null  int64
# dtypes: int64(2)
# memory usage: 11.4 MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500000 entries, 210609 to 710608
# Data columns (total 2 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   epi_year  500000 non-null  int64
#  1   epi_week  500000 non-null  int64
# dtypes: int64(2)
# memory usage: 11.4 MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500000 entries, 710609 to 1210608
# Data columns (total 2 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   epi_year  500000 non-null  int64
#  1   epi_week  500000 non-null  int64
# dtypes: int64(2)
# memory usage: 11.4 MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500000 entries, 1210609 to 394645
# Data columns (total 2 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   epi_year  500000 non-null  int64
#  1   epi_week  500000 non-null  int64
# dtypes: int64(2)
# memory usage: 11.4 MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500000 entries, 394646 to 894645
# Data columns (total 2 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   epi_year  500000 non-null  int64
#  1   epi_week  500000 non-null  int64
# dtypes: int64(2)
# memory usage: 11.4 MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500000 entries, 894646 to 78587
# Data columns (total 2 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   epi_year  500000 non-null  int64
#  1   epi_week  500000 non-null  int64
# dtypes: int64(2)
# memory usage: 11.4 MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500000 entries, 78588 to 578587
# Data columns (total 2 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   epi_year  500000 non-null  int64
#  1   epi_week  500000 non-null  int64
# dtypes: int64(2)
# memory usage: 11.4 MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500000 entries, 578588 to 1078587
# Data columns (total 2 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   epi_year  500000 non-null  int64
#  1   epi_week  500000 non-null  int64
# dtypes: int64(2)
# memory usage: 11.4 MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500000 entries, 1078588 to 262932
# Data columns (total 2 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   epi_year  500000 non-null  int64
#  1   epi_week  500000 non-null  int64
# dtypes: int64(2)
# memory usage: 11.4 MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500000 entries, 262933 to 762932
# Data columns (total 2 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   epi_year  500000 non-null  int64
#  1   epi_week  500000 non-null  int64
# dtypes: int64(2)
# memory usage: 11.4 MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500000 entries, 762933 to 1262932
# Data columns (total 2 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   epi_year  500000 non-null  int64
#  1   epi_week  500000 non-null  int64
# dtypes: int64(2)
# memory usage: 11.4 MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500000 entries, 1262933 to 448947
# Data columns (total 2 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   epi_year  500000 non-null  int64
#  1   epi_week  500000 non-null  int64
# dtypes: int64(2)
# memory usage: 11.4 MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500000 entries, 448948 to 948947
# Data columns (total 2 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   epi_year  500000 non-null  int64
#  1   epi_week  500000 non-null  int64
# dtypes: int64(2)
# memory usage: 11.4 MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500000 entries, 948948 to 137015
# Data columns (total 2 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   epi_year  500000 non-null  int64
#  1   epi_week  500000 non-null  int64
# dtypes: int64(2)
# memory usage: 11.4 MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500000 entries, 137016 to 637015
# Data columns (total 2 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   epi_year  500000 non-null  int64
#  1   epi_week  500000 non-null  int64
# dtypes: int64(2)
# memory usage: 11.4 MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500000 entries, 637016 to 1137015
# Data columns (total 2 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   epi_year  500000 non-null  int64
#  1   epi_week  500000 non-null  int64
# dtypes: int64(2)
# memory usage: 11.4 MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500000 entries, 1137016 to 326384
# Data columns (total 2 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   epi_year  500000 non-null  int64
#  1   epi_week  500000 non-null  int64
# dtypes: int64(2)
# memory usage: 11.4 MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500000 entries, 326385 to 826384
# Data columns (total 2 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   epi_year  500000 non-null  int64
#  1   epi_week  500000 non-null  int64
# dtypes: int64(2)
# memory usage: 11.4 MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500000 entries, 826385 to 18631
# Data columns (total 2 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   epi_year  500000 non-null  int64
#  1   epi_week  500000 non-null  int64
# dtypes: int64(2)
# memory usage: 11.4 MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500000 entries, 18632 to 518631
# Data columns (total 2 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   epi_year  500000 non-null  int64
#  1   epi_week  500000 non-null  int64
# dtypes: int64(2)
# memory usage: 11.4 MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500000 entries, 518632 to 1018631
# Data columns (total 2 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   epi_year  500000 non-null  int64
#  1   epi_week  500000 non-null  int64
# dtypes: int64(2)
# memory usage: 11.4 MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500000 entries, 1018632 to 213008
# Data columns (total 2 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   epi_year  500000 non-null  int64
#  1   epi_week  500000 non-null  int64
# dtypes: int64(2)
# memory usage: 11.4 MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500000 entries, 213009 to 713008
# Data columns (total 2 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   epi_year  500000 non-null  int64
#  1   epi_week  500000 non-null  int64
# dtypes: int64(2)
# memory usage: 11.4 MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500000 entries, 713009 to 1213008
# Data columns (total 2 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   epi_year  500000 non-null  int64
#  1   epi_week  500000 non-null  int64
# dtypes: int64(2)
# memory usage: 11.4 MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500000 entries, 1213009 to 406207
# Data columns (total 2 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   epi_year  500000 non-null  int64
#  1   epi_week  500000 non-null  int64
# dtypes: int64(2)
# memory usage: 11.4 MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 138125 entries, 406208 to 544332
# Data columns (total 2 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   epi_year  138125 non-null  int64
#  1   epi_week  138125 non-null  int64
# dtypes: int64(2)
# memory usage: 3.2 MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200246 entries, 0 to 200245
# Data columns (total 3 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   epi_year   200246 non-null  int64
#  1   epi_week   200246 non-null  int64
#  2   fallecido  200246 non-null  int64
# dtypes: int64(3)
# memory usage: 4.6 MB
# /tmp/ipykernel_47747/681371857.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chunk['vacunado'] = 1
